# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
forex = pd.read_csv("../data/forex_price_data.csv")

trade_log = pd.read_csv("../data/trade_log.csv")

mc = pd.read_csv("../data/mc_scenarios.csv")

# %%
forex.head()
# Out:
#               DateTime  PairID PairName     Open     High      Low    Close  \
# 0  2023-01-01 00:00:00       1  EUR/USD  1.08103  1.08103  1.08019  1.08054
# 1  2023-01-01 01:00:00       1  EUR/USD  1.08010  1.08043  1.07974  1.08028
# 2  2023-01-01 02:00:00       1  EUR/USD  1.08036  1.08158  1.07961  1.08054
# 3  2023-01-01 03:00:00       1  EUR/USD  1.08068  1.08126  1.07973  1.08088
# 4  2023-01-01 04:00:00       1  EUR/USD  1.08042  1.08042  1.07967  1.08030
#
#    Volume  Spread
# 0    2651     0.9
# 1    2292     1.0
# 2    1796     1.2
# 3    4019     1.4
# 4    2207     1.6

# %%
forex.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  500 non-null    str
#  1   PairID    500 non-null    int64
#  2   PairName  500 non-null    str
#  3   Open      500 non-null    float64
#  4   High      500 non-null    float64
#  5   Low       500 non-null    float64
#  6   Close     500 non-null    float64
#  7   Volume    500 non-null    int64
#  8   Spread    500 non-null    float64
# dtypes: float64(5), int64(2), str(2)
# memory usage: 35.3 KB

# %%
forex.describe()
# Out:
#        PairID        Open        High         Low       Close        Volume  \
# count   500.0  500.000000  500.000000  500.000000  500.000000    500.000000
# mean      1.0    1.088002    1.088494    1.087540    1.088007   3368.230000
# std       0.0    0.015255    0.015222    0.015234    0.015236   1697.493162
# min       1.0    1.065410    1.065900    1.064320    1.065750    788.000000
# 25%       1.0    1.074313    1.074982    1.073948    1.074315   2173.000000
# 50%       1.0    1.083095    1.083570    1.082685    1.082990   2990.000000
# 75%       1.0    1.104668    1.104963    1.104078    1.104763   4056.750000
# max       1.0    1.118660    1.118660    1.117880    1.118130  13023.000000
#
#            Spread
# count  500.000000
# mean     1.405600
# std      0.358756
# min      0.800000
# 25%      1.100000
# 50%      1.400000
# 75%      1.700000
# max      2.000000

# %%
forex.isnull().sum()
# Out:
# DateTime    0
# PairID      0
# PairName    0
# Open        0
# High        0
# Low         0
# Close       0
# Volume      0
# Spread      0
# dtype: int64

# %%
print("Rows:", forex.shape[0])
print("Columns:", forex.shape[1])
# Out:
# Rows: 500
# Columns: 9

# %%
forex["PairName"].value_counts()
# Out:
# PairName
# EUR/USD    500
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))

plt.plot(forex["Close"])

plt.title("Forex Closing Price Trend")

plt.show()

# %%
plt.figure(figsize=(12,5))

plt.plot(forex["Volume"])

plt.title("Volume Trend")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(forex["Spread"])

plt.title("Spread Distribution")

plt.show()
